# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\Dell\Downloads\Book1.xlsx")

# %%
df
# Out:
#                Name        Date Days Shift     In  Lunch Out  Lunch In    Out  \
# 0     Nachiket Soni  01/06/2024  Sat   S01    NaN        NaN       NaN    NaN
# 1     Nachiket Soni  02/06/2024  Sun   OFF    NaN        NaN       NaN    NaN
# 2     Nachiket Soni  03/06/2024  Mon   S01  10:27        NaN       NaN  19:41
# 3     Nachiket Soni  04/06/2024  Tue   S01  10:45        NaN       NaN  20:01
# 4     Nachiket Soni  05/06/2024  Wed   S01  11:12        NaN       NaN  19:48
# ..              ...         ...  ...   ...    ...        ...       ...    ...
# 204  Navshree Yadav  26/06/2024  Wed   S01  10:55        NaN       NaN  19:41
# 205  Navshree Yadav  27/06/2024  Thu   S01  12:18        NaN       NaN  19:38
# 206  Navshree Yadav  28/06/2024  Fri   S01  10:54        NaN       NaN  20:09
# 207  Navshree Yadav  29/06/2024  Sat   S01  10:35        NaN       NaN  20:10
# 208  Navshree Yadav  30/06/2024  Sun   OFF    NaN        NaN       NaN    NaN
#
# ...

# %%
df.head(30)
# Out:
#              Name        Date Days Shift     In  Lunch Out  Lunch In    Out  \
# 0   Nachiket Soni  01/06/2024  Sat   S01    NaN        NaN       NaN    NaN
# 1   Nachiket Soni  02/06/2024  Sun   OFF    NaN        NaN       NaN    NaN
# 2   Nachiket Soni  03/06/2024  Mon   S01  10:27        NaN       NaN  19:41
# 3   Nachiket Soni  04/06/2024  Tue   S01  10:45        NaN       NaN  20:01
# 4   Nachiket Soni  05/06/2024  Wed   S01  11:12        NaN       NaN  19:48
# 5   Nachiket Soni  06/06/2024  Thu   S01  10:41        NaN       NaN  19:36
# 6   Nachiket Soni  07/06/2024  Fri   S01  10:42        NaN       NaN  19:42
# 7   Nachiket Soni  08/06/2024  Sat   S01    NaN        NaN       NaN    NaN
# 8   Nachiket Soni  09/06/2024  Sun   OFF    NaN        NaN       NaN    NaN
# 9   Nachiket Soni  10/06/2024  Mon   S01  11:14        NaN       NaN  19:23
# 10  Nachiket Soni  11/06/2024  Tue   S01  10:55        NaN       NaN  19:31
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           209 non-null    object
#  1   Date           209 non-null    object
#  2   Days           209 non-null    object
#  3   Shift          209 non-null    object
#  4   In             101 non-null    object
#  5   Lunch Out      0 non-null      float64
#  6   Lunch In       0 non-null      float64
#  7   Out            99 non-null     object
#  8   Shift Late     27 non-null     object
#  9   Shift Early    12 non-null     object
#  10  Hours Worked   73 non-null     object
#  11  Decimal Hours  209 non-null    float64
#  12  Over Time      209 non-null    float64
#  13  Status         209 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 23.0+ KB

# %%
df.drop(['Lunch Out', 'Lunch In'],axis=1,inplace=True)

# %%
df
# Out:
#                Name        Date Days Shift     In    Out Shift Late  \
# 0     Nachiket Soni  01/06/2024  Sat   S01    NaN    NaN        NaN
# 1     Nachiket Soni  02/06/2024  Sun   OFF    NaN    NaN        NaN
# 2     Nachiket Soni  03/06/2024  Mon   S01  10:27  19:41        NaN
# 3     Nachiket Soni  04/06/2024  Tue   S01  10:45  20:01      00:15
# 4     Nachiket Soni  05/06/2024  Wed   S01  11:12  19:48      00:42
# ..              ...         ...  ...   ...    ...    ...        ...
# 204  Navshree Yadav  26/06/2024  Wed   S01  10:55  19:41      00:25
# 205  Navshree Yadav  27/06/2024  Thu   S01  12:18  19:38      01:48
# 206  Navshree Yadav  28/06/2024  Fri   S01  10:54  20:09      00:24
# 207  Navshree Yadav  29/06/2024  Sat   S01  10:35  20:10        NaN
# 208  Navshree Yadav  30/06/2024  Sun   OFF    NaN    NaN        NaN
#
#     Shift Early Hours Worked  Decimal Hours  Over Time Status
# 0           NaN          NaN       0.000000   0.000000      A
# ...

# %%
df['Date']
# Out:
# 0      01/06/2024
# 1      02/06/2024
# 2      03/06/2024
# 3      04/06/2024
# 4      05/06/2024
#           ...
# 204    26/06/2024
# 205    27/06/2024
# 206    28/06/2024
# 207    29/06/2024
# 208    30/06/2024
# Name: Date, Length: 209, dtype: object

# %%
df.fillna({'Hours Worked':0,'Overtime':0},inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# Name               0
# Date               0
# Days               0
# Shift              0
# In               108
# Out              110
# Shift Late       182
# Shift Early      197
# Hours Worked       0
# Decimal Hours      0
# Over Time          0
# Status             0
# dtype: int64

# %%
df
# Out:
#                Name        Date Days Shift     In    Out Shift Late  \
# 0     Nachiket Soni  01/06/2024  Sat   S01    NaN    NaN        NaN
# 1     Nachiket Soni  02/06/2024  Sun   OFF    NaN    NaN        NaN
# 2     Nachiket Soni  03/06/2024  Mon   S01  10:27  19:41        NaN
# 3     Nachiket Soni  04/06/2024  Tue   S01  10:45  20:01      00:15
# 4     Nachiket Soni  05/06/2024  Wed   S01  11:12  19:48      00:42
# ..              ...         ...  ...   ...    ...    ...        ...
# 204  Navshree Yadav  26/06/2024  Wed   S01  10:55  19:41      00:25
# 205  Navshree Yadav  27/06/2024  Thu   S01  12:18  19:38      01:48
# 206  Navshree Yadav  28/06/2024  Fri   S01  10:54  20:09      00:24
# 207  Navshree Yadav  29/06/2024  Sat   S01  10:35  20:10        NaN
# 208  Navshree Yadav  30/06/2024  Sun   OFF    NaN    NaN        NaN
#
#     Shift Early Hours Worked  Decimal Hours  Over Time Status
# 0           NaN            0       0.000000   0.000000      A
# ...

# %%
df.head(30)
# Out:
#              Name        Date Days Shift     In    Out Shift Late Shift Early  \
# 0   Nachiket Soni  01/06/2024  Sat   S01    NaN    NaN        NaN         NaN
# 1   Nachiket Soni  02/06/2024  Sun   OFF    NaN    NaN        NaN         NaN
# 2   Nachiket Soni  03/06/2024  Mon   S01  10:27  19:41        NaN         NaN
# 3   Nachiket Soni  04/06/2024  Tue   S01  10:45  20:01      00:15         NaN
# 4   Nachiket Soni  05/06/2024  Wed   S01  11:12  19:48      00:42         NaN
# 5   Nachiket Soni  06/06/2024  Thu   S01  10:41  19:36      00:11         NaN
# 6   Nachiket Soni  07/06/2024  Fri   S01  10:42  19:42      00:12         NaN
# 7   Nachiket Soni  08/06/2024  Sat   S01    NaN    NaN        NaN         NaN
# 8   Nachiket Soni  09/06/2024  Sun   OFF    NaN    NaN        NaN         NaN
# 9   Nachiket Soni  10/06/2024  Mon   S01  11:14  19:23      00:44         NaN
# 10  Nachiket Soni  11/06/2024  Tue   S01  10:55  19:31      00:25         NaN
# ...

# %%
print(df.columns)
# Out:
# Index(['Name', 'Date', 'Days', 'Shift', 'In', 'Out', 'Shift Late',
#        'Shift Early', 'Hours Worked', 'Decimal Hours', 'Over Time', 'Status'],
#       dtype='object')

# %%
total_days=df['Date'].nunique()
print(f"Total Days:{total_days}")
# Out:
# Total Days:30

# %%
present_days = df[df['Status'].isin(['P'])].shape[0]
print(f"Total Present Days: {present_days}")
# Out:
# Total Present Days: 71

# %%
status_counts = df['Status'].value_counts()
print(status_counts)
# Out:
# A      101
# P       71
# WO      33
# MIS      2
# POW      1
# HLF      1
# Name: Status, dtype: int64

# %%
df['Status'].unique()
print(f"{'Name'}:{' Nchiket Soni'} ")
# Out:
# Name: Nchiket Soni

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
unique_statuses = df['Status'].unique()
print(unique_statuses)
# Out:
# ['A' 'WO' 'P' 'MIS' 'POW' 'HLF']

# %%
total_days = df['Date'].nunique()
print(f"Total Days:{total_days}")
# Out:
# Total Days:30

# %%
present_days = df[df['Status'].isin(['P', 'MIS', 'Half Day'])].shape[0]
print(f"Total Present Days: {present_days}")
# Out:
# Total Present Days: 73

# %%
absent_days = df[df['Status'] == 'A'].shape[0]
print(f"Total Absent Days: {absent_days}")
# Out:
# Total Absent Days: 101

# %%
df['Hours Worked']=df['Hours Worked'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 df['Hours Worked']=df['Hours Worked'].astype('int')
#
# File ~\anaconda3\anacondaa\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\anacondaa\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
print(df['Hours Worked'].unique())
df['Hours Worked'] = pd.to_numeric(df['Hours Worked'], errors='coerce')
print(df[df['Hours Worked'].isna()])
df['Hours Worked'].fillna(0,inplace=True)
total_hours_worked = df['Hours Worked'].sum()
print(f"Total Hours Worked: {total_hours_worked}")
# Out:
# [0 '09:14' '09:16' '08:36' '08:55' '09:00' '08:09' '08:28' '09:03' '08:58'
#  '08:40' '08:08' '09:08' '08:51' '08:22' '08:50' '09:09' '09:06' '05:55'
#  '08:59' '08:37' '08:39' '09:02' '08:45' '07:26' '09:46' '08:54' '03:00'
#  '09:17' '09:07' '04:35' '08:44' '09:45' '09:19' '09:29' '09:30' '09:27'
#  '07:18' '09:13' '07:15' '09:52' '07:57' '08:33' '08:57' '09:11' '09:12'
#  '08:49' '09:04' '09:10' '08:46' '07:20' '09:15' '09:35']
#                Name        Date Days Shift     In    Out Shift Late  \
# 2     Nachiket Soni  03/06/2024  Mon   S01  10:27  19:41        NaN
# 3     Nachiket Soni  04/06/2024  Tue   S01  10:45  20:01      00:15
# 4     Nachiket Soni  05/06/2024  Wed   S01  11:12  19:48      00:42
# 5     Nachiket Soni  06/06/2024  Thu   S01  10:41  19:36      00:11
# 6     Nachiket Soni  07/06/2024  Fri   S01  10:42  19:42      00:12
# ..              ...         ...  ...   ...    ...    ...        ...
# 203  Navshree Yadav  25/06/2024  Tue   S01  10:45  19:55      00:15
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Status', data=df)
plt.title('Attendance Status Distribution')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12, 8))
employee_hours = df.groupby('Name')['Hours Worked'].sum().reset_index()
sns.barplot(x='Name', y='Hours Worked', data=employee_hours)
plt.title('Total Hours Worked by Employee')
plt.xlabel('Name')
plt.ylabel('Total Hours Worked')
plt.xticks(rotation=90)
plt.show()
